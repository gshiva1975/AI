# %%
# Step 1: Exploratory Data Analysis (EDA)
plt.figure(figsize=(18, 14))

# Plot distributions of key features (Danceability, Energy, Acousticness, Tempo)
for i, feature in enumerate(['danceability', 'energy', 'acousticness', 'tempo']):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df_spotify[feature], kde=True, color='skyblue')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Step 1b: Identify Outliers using Boxplots
plt.figure(figsize=(18, 10))

for i, feature in enumerate(['danceability', 'energy', 'acousticness', 'tempo']):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(y=df_spotify[feature], color='lightcoral')
    plt.title(f'Boxplot of {feature}')
    plt.ylabel(feature)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-81b92074df23> in <cell line: 2>()
#       1 # Step 1: Exploratory Data Analysis (EDA)
# ----> 2 plt.figure(figsize=(18, 14))
#       3
#       4 # Plot distributions of key features (Danceability, Energy, Acousticness, Tempo)
#       5 for i, feature in enumerate(['danceability', 'energy', 'acousticness', 'tempo']):
#
# NameError: name 'plt' is not defined
